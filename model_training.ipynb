# %%
# !yolo task=detect mode=train model=yolov8x data="/Users/ioanbsu/git/ml_smart_home/datasets/yolo_datasetSplit/data.yaml"   batch=10 epochs=50 imgsz=640 device="mps" cache=ram
# Out:
# New https://pypi.org/project/ultralytics/8.0.121 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.103 🚀 Python-3.10.10 torch-2.0.0 MPS
# ...
